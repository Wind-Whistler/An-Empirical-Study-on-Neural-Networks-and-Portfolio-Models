# %%
import numpy as np
import pandas as pd

# %%
T_return=pd.read_excel(r"E:\大三\大三上\Optimization in Finance\Final Project\Portefolio\Effect and Compare\HY\True\宽泛修正训练数据.xlsx")
Tr=np.array(T_return.iloc[0:,1:])
Tr.shape
# Out:
# (3, 499)

# %%
returns=np.zeros(3)
for i in range(3):
    path="E:/大三/大三上/Optimization in Finance/Final Project/Portefolio/Effect and Compare/HY/HY Weight/"+f"HY{i+1}.csv"
    w=pd.read_csv(path)
    weights=np.array(w.iloc[:,1])
    returns[i]=Tr[i,:]@weights
print(returns)
# Out:
# [0.25076617 0.24401715 0.39240387]
