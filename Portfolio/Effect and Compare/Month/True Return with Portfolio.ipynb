# %%
import numpy as np
import pandas as pd

# %%
T_return=pd.read_excel(r"E:\大三\大三上\Optimization in Finance\Final Project\Portefolio\Effect and Compare\Month\宽泛修正训练数据.xlsx")
Tr=np.array(T_return.iloc[0:,1:])
Tr.shape
# Out:
# (23, 499)

# %%
returns=np.zeros(23)
for i in range(23):
    path="E:/大三/大三上/Optimization in Finance/Final Project/Portefolio/Effect and Compare/Month/Month Weight/"+f"Month{i+1}.csv"
    w=pd.read_csv(path)
    weights=np.array(w.iloc[:,1])
    returns[i]=Tr[i,:]@weights
print(returns)
# Out:
# [0.20666929 0.20782651 0.20466911 0.14231712 0.21971448 0.11438017
#  0.10767889 0.2631395  0.16226249 0.03960508 0.17516019 0.1149394
#  0.19820717 0.15865444 0.14707221 0.11155874 0.19223983 0.16460386
#  0.11422553 0.23859591 0.05406288 0.16992384 0.11529697]
