# %%
import numpy as np
import pandas as pd

# %%
T_return=pd.read_excel(r"E:\大三\大三上\Optimization in Finance\Final Project\Portefolio\Effect and Compare\Season\宽泛修正训练数据.xlsx")
Tr=np.array(T_return.iloc[0:,1:])
Tr.shape
# Out:
# (7, 499)

# %%
returns=np.zeros(7)
for i in range(7):
    path="E:/大三/大三上/Optimization in Finance/Final Project/Portefolio/Effect and Compare/Season/Season Weight/"+f"Season{i+1}.csv"
    w=pd.read_csv(path)
    weights=np.array(w.iloc[:,1])
    returns[i]=Tr[i,:]@weights
print(returns)
# Out:
# [-0.00282143  0.1610477   0.16721455  0.20854242  0.21168576  0.3726827
#   0.05430751]
